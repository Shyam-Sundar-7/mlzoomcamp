# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('PeopleCare_TrainData.csv')
df.head()
# Out:
#     id  Gender   Age  Driving_License  Region_Code  Previously_Insured
# 0  1.0    Male  44.0              1.0         28.0                 0.0  \
# 1  2.0    Male  76.0              1.0          3.0                 0.0
# 2  3.0    Male  47.0              1.0         28.0                 0.0
# 3  4.0    Male  21.0              1.0         11.0                 1.0
# 4  5.0  Female  29.0              1.0         41.0                 1.0
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0   > 2 Years            Yes         40454.0                  26.0    217.0  \
# 1    1-2 Year             No         33536.0                  26.0    183.0
# 2   > 2 Years            Yes         38294.0                  26.0     27.0
# 3    < 1 Year             No         28619.0                 152.0    203.0
# 4    < 1 Year             No         27496.0                 152.0     39.0
#
#    Interested in getting Policy from PeopleCare
# ...

# %%
df.rename(columns={'Interested in getting Policy from PeopleCare':'Target'}, inplace=True)

# %%
df.describe(include="all")
# Out:
#                    id Gender           Age  Driving_License   Region_Code
# count    91430.000000  91430  91430.000000     91430.000000  91430.000000  \
# unique            NaN      2           NaN              NaN           NaN
# top               NaN   Male           NaN              NaN           NaN
# freq              NaN  52265           NaN              NaN           NaN
# mean    109614.413726    NaN     40.854009         0.998381     26.577174
# std     114191.490596    NaN     14.330860         0.040201     12.601734
# min          1.000000    NaN     20.000000         0.000000      0.000000
# 25%      22858.250000    NaN     27.000000         1.000000     16.000000
# 50%      45715.500000    NaN     41.000000         1.000000     28.000000
# 75%     194425.250000    NaN     50.000000         1.000000     34.000000
# max     381098.000000    NaN     85.000000         1.000000     52.000000
#
#         Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium
# ...

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# id                      76.008796
# Gender                  76.008796
# Age                     76.008796
# Driving_License         76.008796
# Region_Code             76.008796
# Previously_Insured      76.008796
# Vehicle_Age             76.008796
# Vehicle_Damage          76.008796
# Annual_Premium          76.008796
# Policy_Sales_Channel    76.008796
# Vintage                 76.008796
# Target                  76.008796
# dtype: float64

# %%
df.dropna(inplace=True)

df.describe()
# Out:
#                   id           Age  Driving_License   Region_Code
# count   91430.000000  91430.000000     91430.000000  91430.000000  \
# mean   109614.413726     40.854009         0.998381     26.577174
# std    114191.490596     14.330860         0.040201     12.601734
# min         1.000000     20.000000         0.000000      0.000000
# 25%     22858.250000     27.000000         1.000000     16.000000
# 50%     45715.500000     41.000000         1.000000     28.000000
# 75%    194425.250000     50.000000         1.000000     34.000000
# max    381098.000000     85.000000         1.000000     52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel       Vintage
# count        91430.000000    91430.000000          91430.000000  91430.000000  \
# mean             0.256579    30950.324959            103.297484    154.208542
# std              0.436747    17753.048918             55.866494     83.667594
# ...

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# id                      0.0
# Gender                  0.0
# Age                     0.0
# Driving_License         0.0
# Region_Code             0.0
# Previously_Insured      0.0
# Vehicle_Age             0.0
# Vehicle_Damage          0.0
# Annual_Premium          0.0
# Policy_Sales_Channel    0.0
# Vintage                 0.0
# Target                  0.0
# dtype: float64

# %% [markdown]
# # Analysis of each column

# %%
df.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Target                  0
# dtype: int64

# %%
import sweetviz as sv
sweet_report = sv.analyze(df)
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)

# %%
sweet_report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# Takeaways:
#
# - The customers age varies from 20 to 85 age with maximum number of customers from 20 to 30 years age.
#
# - id is column is not necessary for analysis as it is  IID (independent and identically distributed)
#
# - Most of the customers are having a driving license.
#
# - Median of the annual premium is less than 3000 usd.
#
# - Maximum no. of customers use their vehicle between 1 to 2 year.
#
# - Vintage column is uniformly distributed.
#
# - Target column is evenly distributed with same number of 1's and 0's.

# %% [markdown]
# # Analysis with target

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a cross-tabulation table
cross_tab = pd.crosstab(df['Vehicle_Age'], df['Target'], normalize='index') * 100

# Plot the cross-tabulation table as a bar plot
cross_tab.plot(kind='bar')
plt.xlabel('Vehicle Age')
plt.ylabel('Percentage')
plt.title('Percentage of Target for each Vehicle Age')

plt.show()

# %% [markdown]
# After 1 year, we have higher probability that the customer is interested in opting fot the Vehicle Insurance.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the bar plot
sns.countplot(x='Previously_Insured', hue='Target',data=df)

# Set labels and title
plt.xlabel('Previously Insured')
plt.ylabel('Count')
plt.title('Bar Plot of Previously Insured and Target')

# Show the plot

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the box plot
sns.boxplot(x='Target', y='Annual_Premium', data=df)

# Set labels and title
plt.xlabel('Target')
plt.ylabel('Annual Premium')
plt.title('Box Plot of Annual Premium and Target')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the percentage of each 'Target' category within each 'Gender' category
percentage_df = df.groupby(['Gender', 'Target']).size().unstack() / df.groupby('Gender').size().values[:, None] * 100

# Create the bar plot
percentage_df.plot(kind='bar')

# Set labels and title
plt.xlabel('Gender')
plt.ylabel('Percentage')
plt.title('Percentage of Target by Gender')

# Show the plot
plt.show()

# %% [markdown]
#     Males prefer to go for insurance. But still there isn't big difference between genders.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create the cross-tabulation table and normalize the values
cross_tab = pd.crosstab(df['Driving_License'], df['Target'], normalize='index') * 100

# Plot the cross-tabulation table as a bar plot
cross_tab.plot(kind='bar')

# Set labels and title
plt.xlabel('Driving License')
plt.ylabel('Percentage')
plt.title('Percentage of Target by Driving License')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the count plot
sns.countplot(y='Region_Code', hue='Target', data=df)

# Set labels and title
plt.ylabel('Region Code')
plt.xlabel('Count')
plt.title('Count Plot of Region Code and Target')

# Show the plot
plt.show()

# %% [markdown]
# Equal importance between the Region_Code and Target

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the count plot
sns.countplot(x='Vehicle_Damage', hue='Target', data=df)

# Set labels and title
plt.xlabel('Vehicle Damage')
plt.ylabel('Count')
plt.title('Count Plot of Vehicle Damage and Target')

# Show the plot
plt.show()

# %% [markdown]
# There is increase in customer interest in engaging with an insurance because of the vehicle damage.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the count plot
sns.countplot(y='Policy_Sales_Channel', hue='Target', data=df)

# Set labels and title
plt.ylabel('Policy_Sales_Channel')
plt.xlabel('Count')
plt.title('Count Plot of Policy_Sales_Channel and Target')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
df['MALE']=df['Gender'].apply(lambda x: 1 if x=='Male' else 0)
df['vehicle_d']=df['Vehicle_Damage'].apply(lambda x: 1 if x=='Yes' else 0)
corr_matrix = df[['Age','MALE', 'Annual_Premium', 'Vintage','Driving_License', 'Previously_Insured', 'Policy_Sales_Channel','Target','vehicle_d']].corr()

# Create the heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')

# Set title
plt.title('Correlation Heatmap')

# Show the plot
plt.show()
